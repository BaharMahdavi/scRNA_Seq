# %%
!wget -c https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Out:
# --2024-10-17 12:38:14--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 148981743 (142M) [application/octet-stream]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 142.08M   132MB/s    in 1.1s
#
# 2024-10-17 12:38:15 (132 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [148981743/148981743]

# %%
!chmod +x Miniconda3-latest-Linux-x86_64.sh

# %%
!bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
!conda create -n rsg python=3.8 -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/rsg
#
#   added / updated specs:
#     - python=3.8
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pip-24.2                   |   py38h06a4308_0         2.2 MB
#     python-3.8.20              |       he870216_0        23.8 MB
#     setuptools-75.1.0          |   py38h06a4308_0         1.7 MB
#     wheel-0.44.0               |   py38h06a4308_0         108 KB
#     ------------------------------------------------------------
#                                            Total:        27.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2024.9.24-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.40-h12ee557_0
#   libffi             pkgs/main/linux-64::libffi-3.4.4-h6a678d5_1
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-11.2.0-h1234567_1
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-11.2.0-h1234567_1
#   ncurses            pkgs/main/linux-64::ncurses-6.4-h6a678d5_0
#   openssl            pkgs/main/linux-64::openssl-3.0.15-h5eee18b_0
#   pip                pkgs/main/linux-64::pip-24.2-py38h06a4308_0
#   python             pkgs/main/linux-64::python-3.8.20-he870216_0
#   readline           pkgs/main/linux-64::readline-8.2-h5eee18b_0
#   setuptools         pkgs/main/linux-64::setuptools-75.1.0-py38h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.45.3-h5eee18b_0
#   tk                 pkgs/main/linux-64::tk-8.6.14-h39e8969_0
#   wheel              pkgs/main/linux-64::wheel-0.44.0-py38h06a4308_0
#   xz                 pkgs/main/linux-64::xz-5.4.6-h5eee18b_1
#   zlib               pkgs/main/linux-64::zlib-1.2.13-h5eee18b_1
#
#
#
# Downloading and Extracting Packages:
# python-3.8.20        | 23.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# pip-24.2             | 2.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# setuptools-75.1.0    | 1.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# python-3.8.20        | 23.8 MB   | :   6% 0.055204868837614156/1 [00:00<00:01,  1.81s/it]
#
# setuptools-75.1.0    | 1.7 MB    | :   1% 0.00924925453853649/1 [00:00<00:12, 12.18s/it]
# pip-24.2             | 2.2 MB    | :   9% 0.09195148233083746/1 [00:00<00:01,  1.25s/it]
#
#
# wheel-0.44.0         | 108 KB    | : 100% 1.0/1 [00:00<00:00,  6.96it/s]
#
#
# python-3.8.20        | 23.8 MB   | :  86% 0.8629046759974689/1 [00:00<00:00,  2.41it/s]
# pip-24.2             | 2.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.07s/it]
# pip-24.2             | 2.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.07s/it]
#
# setuptools-75.1.0    | 1.7 MB    | : 100% 1.0/1 [00:01<00:00,  1.07s/it]
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate rsg
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
!conda install -n rsg ipykernel -y
# Out:
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/rsg
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     asttokens-2.0.5            |     pyhd3eb1b0_0          20 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     comm-0.2.1                 |   py38h06a4308_0          14 KB
#     debugpy-1.6.7              |   py38h6a678d5_0         2.0 MB
#     decorator-5.1.1            |     pyhd3eb1b0_0          12 KB
#     executing-0.8.3            |     pyhd3eb1b0_0          18 KB
#     importlib-metadata-7.0.1   |   py38h06a4308_0          40 KB
#     importlib_metadata-7.0.1   |       hd3eb1b0_0           8 KB
#     ipykernel-6.29.5           |   py38h06a4308_0         205 KB
#     ipython-8.12.2             |   py38h06a4308_0         1.1 MB
#     jedi-0.19.1                |   py38h06a4308_0         1.0 MB
#     jupyter_client-8.6.0       |   py38h06a4308_0         183 KB
#     jupyter_core-5.7.2         |   py38h06a4308_0          80 KB
#     libsodium-1.0.18           |       h7b6447c_0         244 KB
#     matplotlib-inline-0.1.6    |   py38h06a4308_0          16 KB
#     nest-asyncio-1.6.0         |   py38h06a4308_0          14 KB
#     packaging-24.1             |   py38h06a4308_0         147 KB
#     parso-0.8.3                |     pyhd3eb1b0_0          70 KB
#     pexpect-4.8.0              |     pyhd3eb1b0_3          53 KB
#     pickleshare-0.7.5          |  pyhd3eb1b0_1003          13 KB
#     platformdirs-3.10.0        |   py38h06a4308_0          33 KB
#     prompt-toolkit-3.0.43      |   py38h06a4308_0         571 KB
#     psutil-5.9.0               |   py38h5eee18b_0         330 KB
#     ptyprocess-0.7.0           |     pyhd3eb1b0_2          17 KB
#     pure_eval-0.2.2            |     pyhd3eb1b0_0          14 KB
#     pygments-2.15.1            |   py38h06a4308_1         1.8 MB
#     python-dateutil-2.9.0post0 |   py38h06a4308_2         279 KB
#     pyzmq-25.1.2               |   py38h6a678d5_0         463 KB
#     six-1.16.0                 |     pyhd3eb1b0_1          18 KB
#     stack_data-0.2.0           |     pyhd3eb1b0_0          22 KB
#     tornado-6.4.1              |   py38h5eee18b_0         644 KB
#     traitlets-5.14.3           |   py38h06a4308_0         179 KB
#     typing_extensions-4.11.0   |   py38h06a4308_0          59 KB
#     wcwidth-0.2.5              |     pyhd3eb1b0_0          26 KB
#     zeromq-4.3.5               |       h6a678d5_0         366 KB
#     zipp-3.20.2                |   py38h06a4308_0          25 KB
#     ------------------------------------------------------------
#                                            Total:        10.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   asttokens          pkgs/main/noarch::asttokens-2.0.5-pyhd3eb1b0_0
#   backcall           pkgs/main/noarch::backcall-0.2.0-pyhd3eb1b0_0
#   comm               pkgs/main/linux-64::comm-0.2.1-py38h06a4308_0
#   debugpy            pkgs/main/linux-64::debugpy-1.6.7-py38h6a678d5_0
#   decorator          pkgs/main/noarch::decorator-5.1.1-pyhd3eb1b0_0
#   executing          pkgs/main/noarch::executing-0.8.3-pyhd3eb1b0_0
#   importlib-metadata pkgs/main/linux-64::importlib-metadata-7.0.1-py38h06a4308_0
#   importlib_metadata pkgs/main/noarch::importlib_metadata-7.0.1-hd3eb1b0_0
#   ipykernel          pkgs/main/linux-64::ipykernel-6.29.5-py38h06a4308_0
#   ipython            pkgs/main/linux-64::ipython-8.12.2-py38h06a4308_0
#   jedi               pkgs/main/linux-64::jedi-0.19.1-py38h06a4308_0
#   jupyter_client     pkgs/main/linux-64::jupyter_client-8.6.0-py38h06a4308_0
#   jupyter_core       pkgs/main/linux-64::jupyter_core-5.7.2-py38h06a4308_0
#   libsodium          pkgs/main/linux-64::libsodium-1.0.18-h7b6447c_0
#   matplotlib-inline  pkgs/main/linux-64::matplotlib-inline-0.1.6-py38h06a4308_0
#   nest-asyncio       pkgs/main/linux-64::nest-asyncio-1.6.0-py38h06a4308_0
#   packaging          pkgs/main/linux-64::packaging-24.1-py38h06a4308_0
#   parso              pkgs/main/noarch::parso-0.8.3-pyhd3eb1b0_0
#   pexpect            pkgs/main/noarch::pexpect-4.8.0-pyhd3eb1b0_3
#   pickleshare        pkgs/main/noarch::pickleshare-0.7.5-pyhd3eb1b0_1003
#   platformdirs       pkgs/main/linux-64::platformdirs-3.10.0-py38h06a4308_0
#   prompt-toolkit     pkgs/main/linux-64::prompt-toolkit-3.0.43-py38h06a4308_0
#   psutil             pkgs/main/linux-64::psutil-5.9.0-py38h5eee18b_0
#   ptyprocess         pkgs/main/noarch::ptyprocess-0.7.0-pyhd3eb1b0_2
#   pure_eval          pkgs/main/noarch::pure_eval-0.2.2-pyhd3eb1b0_0
#   pygments           pkgs/main/linux-64::pygments-2.15.1-py38h06a4308_1
#   python-dateutil    pkgs/main/linux-64::python-dateutil-2.9.0post0-py38h06a4308_2
#   pyzmq              pkgs/main/linux-64::pyzmq-25.1.2-py38h6a678d5_0
#   six                pkgs/main/noarch::six-1.16.0-pyhd3eb1b0_1
#   stack_data         pkgs/main/noarch::stack_data-0.2.0-pyhd3eb1b0_0
#   tornado            pkgs/main/linux-64::tornado-6.4.1-py38h5eee18b_0
#   traitlets          pkgs/main/linux-64::traitlets-5.14.3-py38h06a4308_0
#   typing_extensions  pkgs/main/linux-64::typing_extensions-4.11.0-py38h06a4308_0
#   wcwidth            pkgs/main/noarch::wcwidth-0.2.5-pyhd3eb1b0_0
#   zeromq             pkgs/main/linux-64::zeromq-4.3.5-h6a678d5_0
#   zipp               pkgs/main/linux-64::zipp-3.20.2-py38h06a4308_0
#
#
#
# Downloading and Extracting Packages:
# debugpy-1.6.7        | 2.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
# pygments-2.15.1      | 1.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# ipython-8.12.2       | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# jedi-0.19.1          | 1.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# tornado-6.4.1        | 644 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# prompt-toolkit-3.0.4 | 571 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# pyzmq-25.1.2         | 463 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# zeromq-4.3.5         | 366 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# psutil-5.9.0         | 330 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 279 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 205 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.0 | 183 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-24.1       | 147 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 59 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# pygments-2.15.1      | 1.8 MB    | :   1% 0.00886484146737366/1 [00:00<00:13, 13.27s/it]
#
#
#
#
#
# pyzmq-25.1.2         | 463 KB    | :   3% 0.03458057544238822/1 [00:00<00:03,  3.53s/it]
#
#
#
#
#
#
# zeromq-4.3.5         | 366 KB    | :   4% 0.04367866959208538/1 [00:00<00:03,  3.37s/it]
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 279 KB    | :   6% 0.0573414483055504/1 [00:00<00:03,  3.29s/it]
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | :   7% 0.06546608222418457/1 [00:00<00:02,  2.98s/it]
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 205 KB    | :   8% 0.07794703940169558/1 [00:00<00:02,  2.82s/it]
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.0 | 183 KB    | :   9% 0.08749239034080593/1 [00:00<00:02,  2.79s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | :   9% 0.08943036178249383/1 [00:00<00:02,  2.78s/it]
#
#
#
# tornado-6.4.1        | 644 KB    | : 100% 1.0/1 [00:00<00:00,  3.61it/s]
#
#
#
# tornado-6.4.1        | 644 KB    | : 100% 1.0/1 [00:00<00:00,  3.61it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-24.1       | 147 KB    | :  11% 0.10867964578289277/1 [00:00<00:02,  2.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     | :  20% 0.20034973158712108/1 [00:00<00:01,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# debugpy-1.6.7        | 2.0 MB    | :   1% 0.007784101409965684/1 [00:00<00:40, 40.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | :  30% 0.3047052259624326/1 [00:00<00:00,  1.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 59 KB     | :  27% 0.2725941701051511/1 [00:00<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# debugpy-1.6.7        | 2.0 MB    | :  31% 0.31136405639862735/1 [00:00<00:00,  1.06s/it]
#
#
#
#
#
#
#
# debugpy-1.6.7        | 2.0 MB    | :  61% 0.6149440113872889/1 [00:00<00:00,  1.58it/s]
#
# ipython-8.12.2       | 1.1 MB    | :   1% 0.014300951942028075/1 [00:00<00:37, 37.77s/it]
#
#
#
#
# prompt-toolkit-3.0.4 | 571 KB    | : 100% 1.0/1 [00:00<00:00,  1.72it/s]
#
#
#
#
# debugpy-1.6.7        | 2.0 MB    | :  93% 0.934092169195882/1 [00:00<00:00,  2.06it/s]
#
# ipython-8.12.2       | 1.1 MB    | :   6% 0.0572038077681123/1 [00:00<00:08,  9.37s/it]
#
# ipython-8.12.2       | 1.1 MB    | :  11% 0.1144076155362246/1 [00:00<00:04,  4.97s/it]
#
#
#
#
#
# pyzmq-25.1.2         | 463 KB    | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
#
#
#
#
#
# pyzmq-25.1.2         | 463 KB    | : 100% 1.0/1 [00:00<00:00,  1.27it/s]
#
#
#
#
#
#
# zeromq-4.3.5         | 366 KB    | : 100% 1.0/1 [00:00<00:00,  1.18it/s]
#
#
#
#
#
#
# zeromq-4.3.5         | 366 KB    | : 100% 1.0/1 [00:00<00:00,  1.18it/s]
#
# ipython-8.12.2       | 1.1 MB    | :  20% 0.20021332718839305/1 [00:00<00:02,  2.99s/it]
#
# ipython-8.12.2       | 1.1 MB    | :  36% 0.3575237985507019/1 [00:01<00:01,  1.60s/it]
#
# ipython-8.12.2       | 1.1 MB    | :  47% 0.47193141408692646/1 [00:01<00:00,  1.33s/it]
#
# ipython-8.12.2       | 1.1 MB    | :  64% 0.6435428373912634/1 [00:01<00:00,  1.00s/it]
#
# ipython-8.12.2       | 1.1 MB    | :  92% 0.9152609242897968/1 [00:01<00:00,  1.47it/s]
# pygments-2.15.1      | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.36s/it]
# pygments-2.15.1      | 1.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.36s/it]
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 279 KB    | : 100% 1.0/1 [00:01<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
# python-dateutil-2.9. | 279 KB    | : 100% 1.0/1 [00:01<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | : 100% 1.0/1 [00:01<00:00,  1.47s/it]
#
#
#
#
#
#
#
#
#
# libsodium-1.0.18     | 244 KB    | : 100% 1.0/1 [00:01<00:00,  1.47s/it]
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 205 KB    | : 100% 1.0/1 [00:01<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
#
#
# ipykernel-6.29.5     | 205 KB    | : 100% 1.0/1 [00:01<00:00,  1.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# traitlets-5.14.3     | 179 KB    | : 100% 1.0/1 [00:01<00:00,  1.67s/it]
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.0 | 183 KB    | : 100% 1.0/1 [00:01<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
#
#
# jupyter_client-8.6.0 | 183 KB    | : 100% 1.0/1 [00:01<00:00,  1.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-24.1       | 147 KB    | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# packaging-24.1       | 147 KB    | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
#
#
# jedi-0.19.1          | 1.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
#
#
# jedi-0.19.1          | 1.0 MB    | : 100% 1.0/1 [00:01<00:00,  1.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     | : 100% 1.0/1 [00:01<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jupyter_core-5.7.2   | 80 KB     | : 100% 1.0/1 [00:01<00:00,  1.98s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | : 100% 1.0/1 [00:01<00:00,  1.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# parso-0.8.3          | 70 KB     | : 100% 1.0/1 [00:01<00:00,  1.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | : 100% 1.0/1 [00:01<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pexpect-4.8.0        | 53 KB     | : 100% 1.0/1 [00:01<00:00,  2.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 59 KB     | : 100% 1.0/1 [00:01<00:00,  2.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# typing_extensions-4. | 59 KB     | : 100% 1.0/1 [00:01<00:00,  2.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
# psutil-5.9.0         | 330 KB    | : 100% 1.0/1 [00:02<00:00,  2.03s/it]
#
#
#
#
#
#
#
# psutil-5.9.0         | 330 KB    | : 100% 1.0/1 [00:02<00:00,  2.03s/it]
#
# debugpy-1.6.7        | 2.0 MB    | : 100% 1.0/1 [00:02<00:00,  2.06it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
!conda run -n rsg python -m ipykernel install --user --name rsg --display-name "rsg"
# Out:
# Installed kernelspec rsg in /root/.local/share/jupyter/kernels/rsg

# %%
!pip install scanpy
# Out:
# Collecting scanpy
#   Downloading scanpy-1.10.3-py3-none-any.whl.metadata (9.4 kB)
# Collecting anndata>=0.8 (from scanpy)
#   Downloading anndata-0.10.9-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: h5py>=3.1 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.11.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.4.2)
# Collecting legacy-api-wrap>=1.4 (from scanpy)
#   Downloading legacy_api_wrap-1.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.7.1)
# Requirement already satisfied: natsort in /usr/local/lib/python3.10/dist-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from scanpy) (3.4)
# Requirement already satisfied: numba>=0.56 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.60.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scanpy) (24.1)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.10/dist-packages (from scanpy) (2.2.2)
# Requirement already satisfied: patsy in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.5.6)
# Collecting pynndescent>=0.5 (from scanpy)
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.5.2)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from scanpy) (1.13.1)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.13.2)
# Collecting session-info (from scanpy)
#   Downloading session_info-1.0.0.tar.gz (24 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: statsmodels>=0.13 in /usr/local/lib/python3.10/dist-packages (from scanpy) (0.14.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from scanpy) (4.66.5)
# Collecting umap-learn!=0.5.0,>=0.5 (from scanpy)
#   Downloading umap_learn-0.5.6-py3-none-any.whl.metadata (21 kB)
# Collecting array-api-compat!=1.5,>1.4 (from anndata>=0.8->scanpy)
#   Downloading array_api_compat-1.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anndata>=0.8->scanpy) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.6->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.56->scanpy) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5->scanpy) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->scanpy) (3.5.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy->scanpy) (1.16.0)
# Collecting stdlib_list (from session-info->scanpy)
#   Downloading stdlib_list-0.11.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading scanpy-1.10.3-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 26.6 MB/s eta 0:00:00
# Downloading anndata-0.10.9-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 9.8 MB/s eta 0:00:00
# Downloading legacy_api_wrap-1.4-py3-none-any.whl (15 kB)
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 4.0 MB/s eta 0:00:00
# Downloading umap_learn-0.5.6-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 6.4 MB/s eta 0:00:00
# Downloading array_api_compat-1.9-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.5 MB/s eta 0:00:00
# Downloading stdlib_list-0.11.0-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.6/83.6 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: session-info
#   Building wheel for session-info (setup.py) ... done
#   Created wheel for session-info: filename=session_info-1.0.0-py3-none-any.whl size=8023 sha256=ada066dc28c35acb497c70c99e7c873256c73e423c9ad13d4f976266811ff1f0
#   Stored in directory: /root/.cache/pip/wheels/6a/aa/b9/eb5d4031476ec10802795b97ccf937b9bd998d68a9b268765a
# Successfully built session-info
# Installing collected packages: array-api-compat, stdlib_list, legacy-api-wrap, session-info, pynndescent, anndata, umap-learn, scanpy
# Successfully installed anndata-0.10.9 array-api-compat-1.9 legacy-api-wrap-1.4 pynndescent-0.5.13 scanpy-1.10.3 session-info-1.0.0 stdlib_list-0.11.0 umap-learn-0.5.6

# %%
# Core scverse libraries
import scanpy as sc
import anndata as ad

# Data retrieval
import pooch

# %%
EXAMPLE_DATA = pooch.create(
    path=pooch.os_cache("scverse_tutorials"),
    base_url="doi:10.6084/m9.figshare.22716739.v1/",
)
EXAMPLE_DATA.load_registry_from_doi()

# %%
samples = {
    "s1d1": "s1d1_filtered_feature_bc_matrix.h5",
    "s1d3": "s1d3_filtered_feature_bc_matrix.h5",
}
adatas = {}

for sample_id, filename in samples.items():
    path = EXAMPLE_DATA.fetch(filename)
    sample_adata = sc.read_10x_h5(path)
    sample_adata.var_names_make_unique()
    adatas[sample_id] = sample_adata

adata = ad.concat(adatas, label="sample")
adata.obs_names_make_unique()
print(adata.obs["sample"].value_counts())
adata
# Out:
# Downloading file 's1d1_filtered_feature_bc_matrix.h5' from 'doi:10.6084/m9.figshare.22716739.v1/s1d1_filtered_feature_bc_matrix.h5' to '/root/.cache/scverse_tutorials'.
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# Downloading file 's1d3_filtered_feature_bc_matrix.h5' from 'doi:10.6084/m9.figshare.22716739.v1/s1d3_filtered_feature_bc_matrix.h5' to '/root/.cache/scverse_tutorials'.
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1756: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# sample
# s1d1    8785
# s1d3    8340
# Name: count, dtype: int64
# /usr/local/lib/python3.10/dist-packages/anndata/_core/anndata.py:1754: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 17125 × 36601
#     obs: 'sample'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 17125 × 36601
#     obs: 'sample'

# %%
adata.obs
# Out:
#                    sample
# AAACCCAAGGATGGCT-1   s1d1
# AAACCCAAGGCCTAGA-1   s1d1
# AAACCCAAGTGAGTGC-1   s1d1
# AAACCCACAAGAGGCT-1   s1d1
# AAACCCACATCGTGGC-1   s1d1
# ...                   ...
# TTTGTTGAGAGTCTGG-1   s1d3
# TTTGTTGCAGACAATA-1   s1d3
# TTTGTTGCATGTTACG-1   s1d3
# TTTGTTGGTAGTCACT-1   s1d3
# TTTGTTGTCGCGCTGA-1   s1d3
#
# [17125 rows x 1 columns]
