# %% [markdown]
# # The Machine Learning Project
# Bahar Mahdavi - SN: 40152521337

# %% [markdown]
# # Working on molecular single-cell lung atlas of lethat COVID-19 data

# %% [markdown]
# # Loading the Datasets:

# %%
import pandas as pd
df = pd.read_csv(r'C:\Bahar\M.Sc Data Mining\Machine Learning (Oct 2022-Feb 2023)\Project\Data\GSM5226574_C51ctr_raw_counts.csv')
df
# Out:
#        Unnamed: 0  TAGGTACCATGGCCAC-1_1  ATTCACTGTAACAGGC-1_1  \
# 0      AL627309.1                     0                     0
# 1      AL627309.5                     0                     0
# 2      AL627309.4                     0                     0
# 3      AL669831.2                     0                     0
# 4       LINC01409                     1                     0
# ...           ...                   ...                   ...
# 34541       VN1R2                     0                     0
# 34542  AL031676.1                     0                     0
# 34543     SMIM34A                     0                     0
# 34544  AL050402.1                     0                     0
# 34545  AL445072.1                     0                     0
#
#        TAACTTCCAACCACGC-1_1  TTGGGTACACGACAAG-1_1  AGGCCACAGAGTCACG-1_1  \
# 0                         0                     0                     0
# 1                         0                     0                     0
# ...

# %%
df.shape
# Out:
# (34546, 6100)

# %%
df.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0  TAGGTACCATGGCCAC-1_1  ATTCACTGTAACAGGC-1_1  \
# 0      AL627309.1                     0                     0
# 1      AL627309.5                     0                     0
# 2      AL627309.4                     0                     0
# 3      AL669831.2                     0                     0
# 4       LINC01409                     1                     0
# ...           ...                   ...                   ...
# 34541       VN1R2                     0                     0
# 34542  AL031676.1                     0                     0
# 34543     SMIM34A                     0                     0
# 34544  AL050402.1                     0                     0
# 34545  AL445072.1                     0                     0
#
#        TAACTTCCAACCACGC-1_1  TTGGGTACACGACAAG-1_1  AGGCCACAGAGTCACG-1_1  \
# 0                         0                     0                     0
# ...

# %%
df.describe()
# Out:
#        TAGGTACCATGGCCAC-1_1  ATTCACTGTAACAGGC-1_1  TAACTTCCAACCACGC-1_1  \
# count          34546.000000          34546.000000          34546.000000
# mean               0.702136              0.550570              0.452874
# std                4.066416              3.607787              3.179249
# min                0.000000              0.000000              0.000000
# 25%                0.000000              0.000000              0.000000
# 50%                0.000000              0.000000              0.000000
# 75%                0.000000              0.000000              0.000000
# max              460.000000            533.000000            410.000000
#
#        TTGGGTACACGACAAG-1_1  AGGCCACAGAGTCACG-1_1  CACTGAAGTCGAAGCA-1_1  \
# count          34546.000000          34546.000000          34546.000000
# mean               0.440572              0.382591              0.368349
# std                2.656428              1.890338              1.701691
# ...

# %%
df.isnull().any()
# Out:
# Unnamed: 0              False
# TAGGTACCATGGCCAC-1_1    False
# ATTCACTGTAACAGGC-1_1    False
# TAACTTCCAACCACGC-1_1    False
# TTGGGTACACGACAAG-1_1    False
#                         ...
# CGCCATTGTTTGCCGG-1_1    False
# CACTGGGGTCTACGTA-1_1    False
# CATACTTGTAGAGGAA-1_1    False
# TTTGGTTTCCACGGAC-1_1    False
# ATGCATGAGTCATGAA-1_1    False
# Length: 6100, dtype: bool

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TAGGTACCATGGCCAC-1_1', 'ATTCACTGTAACAGGC-1_1',
#        'TAACTTCCAACCACGC-1_1', 'TTGGGTACACGACAAG-1_1', 'AGGCCACAGAGTCACG-1_1',
#        'CACTGAAGTCGAAGCA-1_1', 'ACTGATGTCTGCACCT-1_1', 'TTACCGCCACTCAGAT-1_1',
#        'TTGGTTTTCCTAGCTC-1_1',
#        ...
#        'AAGTCGTGTGTGAATA-1_1', 'GTCGTTCTCCAAGGGA-1_1', 'GTTTGGATCGGCCTTT-1_1',
#        'GTACAGTCACGTATAC-1_1', 'TCATGCCCAAGAGGTC-1_1', 'CGCCATTGTTTGCCGG-1_1',
#        'CACTGGGGTCTACGTA-1_1', 'CATACTTGTAGAGGAA-1_1', 'TTTGGTTTCCACGGAC-1_1',
#        'ATGCATGAGTCATGAA-1_1'],
#       dtype='object', length=6100)

# %%
X = df.drop('Unnamed: 0',axis = 1)

# %% [markdown]
# # Dimension Reduction using Principal Component Analysis (PCA):

# %%
import numpy as np
from sklearn.decomposition import PCA
pca = PCA(n_components = 6099)
pca.fit_transform(X)
print(pca.explained_variance_ratio_)
# Out:
# [7.36756219e-01 2.60036654e-02 2.25072622e-02 ... 5.05775808e-07
#  5.05258275e-07 5.03342336e-07]

# %%
pca = PCA(n_components = 30)
pca.fit_transform(X)
print(pca.explained_variance_ratio_)
# Out:
# [7.36756219e-01 2.60036654e-02 2.25072622e-02 1.60542831e-02
#  1.08757795e-02 8.00224111e-03 5.25997044e-03 4.72855404e-03
#  4.12175610e-03 3.60155474e-03 2.83716759e-03 2.09954763e-03
#  1.83019679e-03 1.74639974e-03 1.54937364e-03 1.43887961e-03
#  1.33866899e-03 1.27347925e-03 1.05464627e-03 1.03467711e-03
#  9.63594223e-04 9.16790884e-04 8.32802046e-04 8.07080526e-04
#  7.39358196e-04 7.18238088e-04 6.87675358e-04 6.63406582e-04
#  6.31872708e-04 6.27983517e-04]

# %%
pca = PCA(n_components = 5)
pca.fit_transform(X)
X = pd.DataFrame(pca.transform(X), columns = ['PCA1','PCA2','PCA3','PCA4','PCA5'])
X
# Out:
#            PCA1      PCA2      PCA3      PCA4      PCA5
# 0     -3.735594  2.109779  0.081994  0.515623  0.181190
# 1     -3.208858  1.832447 -0.181439  0.584747  0.137124
# 2     -3.733430  2.159576 -0.014008  0.510213  0.204682
# 3     -3.833511  2.081604  0.054600  0.437761  0.336058
# 4      0.311477  0.053025  0.381225 -0.216610  0.443812
# ...         ...       ...       ...       ...       ...
# 34541 -3.865976  2.098368  0.042806  0.498375  0.230896
# 34542 -3.865976  2.098368  0.042806  0.498375  0.230896
# 34543 -3.865976  2.098368  0.042806  0.498375  0.230896
# 34544 -3.865976  2.098368  0.042806  0.498375  0.230896
# 34545 -3.865976  2.098368  0.042806  0.498375  0.230896
#
# [34546 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
sns.set(style = 'whitegrid')
sns.distplot(X ['PCA1'])
plt.title('Distribution of PCA1', fontsize = 20)
plt.xlabel('Range of PCA1')
plt.ylabel('Count')
plt.show()
warnings.filterwarnings('ignore')

# %%
sns.set(style = 'whitegrid')
sns.distplot(X ['PCA2'])
plt.title('Distribution of PCA2', fontsize = 20)
plt.xlabel('Range of PCA2')
plt.ylabel('Count')
plt.show()

# %%
sns.set(style = 'whitegrid')
sns.distplot(X ['PCA3'])
plt.title('Distribution of PCA3', fontsize = 20)
plt.xlabel('Range of PCA3')
plt.ylabel('Count')
plt.show()

# %%
sns.set(style = 'whitegrid')
sns.distplot(X ['PCA4'])
plt.title('Distribution of PCA4', fontsize = 20)
plt.xlabel('Range of PCA4')
plt.ylabel('Count')
plt.show()

# %%
sns.set(style = 'whitegrid')
sns.distplot(X ['PCA5'])
plt.title('Distribution of PCA5', fontsize = 20)
plt.xlabel('Range of PCA5')
plt.ylabel('Count')
plt.show()

# %%
sns.pairplot(X)

# %%
g = sns.clustermap(X.corr(), 
                   method = 'complete',  
                   cmap = 'coolwarm',
                   annot  = True, 
                   annot_kws = {'size': 14})
plt.setp(g.ax_heatmap.get_xticklabels(), rotation = 60);

# %% [markdown]
# # Building K-Means Clustering:

# %%
x = X.iloc[:, [0,2]].values
print(x.shape)
# Out:
# (34546, 2)

# %%
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
  km.fit(x)
  wcss.append(km.inertia_)
  
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'palevioletred', label = 'Cluster 1')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'cadetblue', label = 'Cluster 2')

plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'midnightblue' , label = 'centeroid')

plt.title('K-Means Clustering')
plt.xlabel('PCA1')
plt.ylabel('PCA3')
plt.legend()
plt.show()

# %%
x = X.iloc[:, [1,2]].values
print(x.shape)
# Out:
# (34546, 2)

# %%
wcss = []
for i in range(1, 11):
  km = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
  km.fit(x)
  wcss.append(km.inertia_)
  
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('wcss')
plt.show()

# %%
km = KMeans(n_clusters = 5, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means == 0, 0], x[y_means == 0, 1], s = 100, c = 'olivedrab', label = 'Cluster 1')
plt.scatter(x[y_means == 1, 0], x[y_means == 1, 1], s = 100, c = 'gold', label = 'Cluster 2')
plt.scatter(x[y_means == 2, 0], x[y_means == 2, 1], s = 100, c = 'turquoise', label = 'Cluster 3')
plt.scatter(x[y_means == 3, 0], x[y_means == 3, 1], s = 100, c = 'mediumvioletred', label = 'Cluster 4')
plt.scatter(x[y_means == 4, 0], x[y_means == 4, 1], s = 100, c = 'orange', label = 'Cluster 5')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.title('K-Means Clustering')
plt.xlabel('PCA2')
plt.ylabel('PCA3')
plt.legend()
plt.show()
